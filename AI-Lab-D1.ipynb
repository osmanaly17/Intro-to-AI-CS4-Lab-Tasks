# %%
print("hello world")
# Out:
# hello world

# %%
number = 420
type(number)
print(number)
# Out:
# 420

# %%
name="you knmow"
name.upper()
len(name)
# Out:
# 9

# %%
a=2
b=3
a+b
# Out:
# 5

# %%
a**b
# Out:
# 8

# %%
num = input("Enter a number ")
# Out:
# Enter a number 55

# %%
for i in range (5):
   print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
numbers = [1,2,3,4,5,5,6,7,8, "hello", True, 'a']

# %%
numbers [4]
# Out:
# 5

# %%
numbers [4] = 55
numbers[4]
# Out:
# 55

# %%
print (numbers)
# Out:
# [1, 2, 3, 4, 55, 5, 6, 7, 8, 'hello', True, 'a']
